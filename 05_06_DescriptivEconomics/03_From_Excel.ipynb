# %% [markdown]
# # Loading and analyzing data from files

# %% [markdown]
# We look at how to:
#
# 1. **Load data** both from files (e.g. Excel or CSV).
# 2. **Clean, structure and analyze data**.
# 3. **Save data** to files (e.g. Excel or CSV).

# %% [markdown]
# **Table of contents**<a id='toc0_'></a>
# - 1. [Employment rate in Danish municipalities](#toc1_)
#   - 1.1. [Step 1: Look at the file](#toc1_1_)
#   - 1.2. [Step 2: Clean up](#toc1_2_)
#     - 1.2.1. [Skip rows and drop columns](#toc1_2_1_)
#     - 1.2.2. [Renaming variables](#toc1_2_2_)
#     - 1.2.3. [Dropping non-municipalities](#toc1_2_3_)
#     - 1.2.4. [Summary statistics](#toc1_2_4_)
#   - 1.3. [Step 3. Structure](#toc1_3_)
# - 2. [Employment and participation rate in Danish municipalities](#toc2_)
# - 3. [Income in Danish municipalities](#toc3_)
# - 4. [Area in Danish municipalities](#toc4_)
# - 5. [Writing data](#toc5_)
# - 6. [Summary](#toc6_)
#
# <!-- vscode-jupyter-toc-config
# 	numbering=true
# 	anchor=true
# 	flat=false
# 	minLevel=2
# 	maxLevel=6
# 	/vscode-jupyter-toc-config -->
# <!-- THIS CELL WILL BE REPLACED ON TOC UPDATE. DO NOT WRITE YOUR TEXT IN THIS CELL -->

# %%
import os 

import pandas as pd

import matplotlib.pyplot as plt
plt.rcParams.update({'axes.grid':True,'grid.color':'black','grid.alpha':'0.25','grid.linestyle':'--'})
plt.rcParams.update({'font.size': 14})

# %% [markdown]
# Pandas offers a lot of facilities for **reading and writing to different formats**. The functions have logical names:
#
# * Excel: `pd.read_excel()`
# * CSV: `pd.read_csv()`
# * SAS: `pd.read_sas()`
# * Stata: `pd.read_stata()`
# * Parquet: `pd.read_parquet()`
#
# And many more...

# %% [markdown]
# **Example:** Raw downloads of Excel-files from [DST](https://www.statbank.dk/statbank5a/SelectTable/Omrade0.asp?PLanguage=1)

# %%
# using assert to check that paths exist on computer.
assert os.path.isdir('data/')
assert os.path.isdir('data/raw')

# print everything in data
os.listdir('data/raw/')
# Out:
# ['ARE207.xlsx',
#  'INDKP101.xlsx',
#  'RAS200.xlsx',
#  'RAS200_only_employment_rate.xlsx']

# %% [markdown]
# ## 1. <a id='toc1_'></a>[Employment rate in Danish municipalities](#toc0_)

# %% [markdown]
# ### 1.1. <a id='toc1_1_'></a>[Step 1: Look at the file](#toc0_)

# %% [markdown]
# Open the file and have a look at it:

# %%
filename = 'data/raw/RAS200_only_employment_rate.xlsx'
pd.read_excel(filename).iloc[:5,:10] # 5 rows, 10 columns
# Out:
#   Activity and employment rates (end November) by frequency, sex, age, ancestry, region and time  \
# 0                                    Units: Per cent
# 1                                                NaN
# 2                                    Employment rate
# 3                                                NaN
# 4                                                NaN
#
#   Unnamed: 1   Unnamed: 2 Unnamed: 3               Unnamed: 4  Unnamed: 5  \
# 0        NaN          NaN        NaN                      NaN         NaN
# 1        NaN          NaN        NaN                      NaN      2008.0
# 2      Total  16-64 years      Total              All Denmark        76.0
# 3        NaN          NaN        NaN       Region Hovedstaden        75.8
# 4        NaN          NaN        NaN  Province Byen København        73.4
#
#    Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9
# 0         NaN         NaN         NaN         NaN
# 1      2009.0      2010.0      2011.0      2012.0
# 2        72.8        72.1        71.8        71.3
# 3        73.3        72.6        72.5        72.2
# 4        71.0        70.5        70.5        70.4

# %% [markdown]
# ### 1.2. <a id='toc1_2_'></a>[Step 2: Clean up](#toc0_)

# %% [markdown]
# We need to clean this *mess* up.

# %% [markdown]
# #### 1.2.1. <a id='toc1_2_1_'></a>[Skip rows and drop columns](#toc0_)

# %% [markdown]
# **Skipping rows:** Clearly, we should **skip** the first three rows and the first four columns

# %%
RAS = pd.read_excel(filename,skiprows=2)
RAS.iloc[:5,:10]
# Out:
#         Unnamed: 0 Unnamed: 1   Unnamed: 2 Unnamed: 3  \
# 0  Employment rate      Total  16-64 years      Total
# 1              NaN        NaN          NaN        NaN
# 2              NaN        NaN          NaN        NaN
# 3              NaN        NaN          NaN        NaN
# 4              NaN        NaN          NaN        NaN
#
#                 Unnamed: 4  2008  2009  2010  2011  2012
# 0              All Denmark  76.0  72.8  72.1  71.8  71.3
# 1       Region Hovedstaden  75.8  73.3  72.6  72.5  72.2
# 2  Province Byen København  73.4  71.0  70.5  70.5  70.4
# 3               Copenhagen  72.5  70.0  69.7  69.6  69.4
# 4            Frederiksberg  75.6  73.7  72.7  72.8  73.0

# %% [markdown]
# **Dropping columns:** The first couple of columns are not needed and contain only missing values (denoted by `NaN`, not-a-number), so we will drop those.

# %%
drop_these = ['Unnamed: ' + str(num) for num in range(4)] # use list comprehension to create list of columns
print('drop these:',drop_these)

RAS = RAS.drop(drop_these,axis=1,) # axis = 1 -> columns
RAS.iloc[:5,:5]
# Out:
# drop these: ['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3']
#                 Unnamed: 4  2008  2009  2010  2011
# 0              All Denmark  76.0  72.8  72.1  71.8
# 1       Region Hovedstaden  75.8  73.3  72.6  72.5
# 2  Province Byen København  73.4  71.0  70.5  70.5
# 3               Copenhagen  72.5  70.0  69.7  69.6
# 4            Frederiksberg  75.6  73.7  72.7  72.8

# %% [markdown]
# #### 1.2.2. <a id='toc1_2_2_'></a>[Renaming variables](#toc0_)

# %% [markdown]
# We are not happy with the column comprising regions, which is currently called `Unnamed: 4`.

# %%
RAS = RAS.rename(columns={'Unnamed: 4':'municipality'})
RAS.iloc[:5,:5]
# Out:
#               municipality  2008  2009  2010  2011
# 0              All Denmark  76.0  72.8  72.1  71.8
# 1       Region Hovedstaden  75.8  73.3  72.6  72.5
# 2  Province Byen København  73.4  71.0  70.5  70.5
# 3               Copenhagen  72.5  70.0  69.7  69.6
# 4            Frederiksberg  75.6  73.7  72.7  72.8

# %% [markdown]
# **Rename all year columns:** We also see that the employment rate in 2008 has been named `2008`.
#
# This is allowed in Python, but having a **variable named as a number** can cause **problems** with some functions.
#
# To change all columns, we need to create a dictionary that maps each of the years {2008, ..., 2013} to {emp_rate2008, ...,emp_rate2013}.

# %%
col_dict = {str(i) : f'emp_rate{i}' for i in RAS.columns[1:]}

# %%
RAS = RAS.rename(columns=col_dict)
RAS.head(5).iloc[:,0:5]
# Out:
#               municipality  emp_rate2008  emp_rate2009  emp_rate2010  \
# 0              All Denmark          76.0          72.8          72.1
# 1       Region Hovedstaden          75.8          73.3          72.6
# 2  Province Byen København          73.4          71.0          70.5
# 3               Copenhagen          72.5          70.0          69.7
# 4            Frederiksberg          75.6          73.7          72.7
#
#    emp_rate2011
# 0          71.8
# 1          72.5
# 2          70.5
# 3          69.6
# 4          72.8

# %% [markdown]
# **Note:** It is a good idea *note* to put *white spaces* in column names. You can theoretically have a column such as RAS['emp_rate 2017'] in a pandas df, but this is *very likely* to get messy. And you can no longer use `.`notation.

# %% [markdown]
# **Extract:** Now we can find the employment rate in the municipality of Copenhagen:

# %%
RAS.loc[RAS.municipality == 'Copenhagen']
# Out:
#   municipality  emp_rate2008  emp_rate2009  emp_rate2010  emp_rate2011  \
# 3   Copenhagen          72.5          70.0          69.7          69.6
#
#    emp_rate2012  emp_rate2013  emp_rate2014  emp_rate2015  emp_rate2016  \
# 3          69.4          69.7          70.0          70.8          71.5
#
#    emp_rate2017  emp_rate2018  emp_rate2019  emp_rate2020  emp_rate2021  \
# 3          72.2          73.2          73.9          72.8          76.1
#
#    emp_rate2022  emp_rate2023
# 3          76.7          76.8

# %% [markdown]
# #### 1.2.3. <a id='toc1_2_3_'></a>[Dropping non-municipalities](#toc0_)
#
# The dataset contains observations like "Region Hovedstaden", which is not a municipality, so we want to drop such rows. To do this, we can use the `df['var'].str` functionalities. These are all sorts of functions that work with strings, in particular searching for instances of specific content by `df['var'].str.contains('PATTERN')`.

# %%
# build up a logical index I
I = RAS.municipality.str.contains('Region')
I |= RAS.municipality.str.contains('Province')
I |= RAS.municipality.str.contains('All Denmark')
RAS.loc[I,:].iloc[:5,:5]
# Out:
#                  municipality  emp_rate2008  emp_rate2009  emp_rate2010  \
# 0                 All Denmark          76.0          72.8          72.1
# 1          Region Hovedstaden          75.8          73.3          72.6
# 2     Province Byen København          73.4          71.0          70.5
# 7   Province Københavns omegn          77.1          74.2          73.2
# 21      Province Nordsjælland          79.4          76.9          76.3
#
#     emp_rate2011
# 0           71.8
# 1           72.5
# 2           70.5
# 7           73.0
# 21          76.1

# %% [markdown]
# **Delete these rows:**

# %%
RAS = RAS.loc[I==False] # keep everything else
RAS.head(10)
# Out:
#      municipality  emp_rate2008  emp_rate2009  emp_rate2010  emp_rate2011  \
# 3      Copenhagen          72.5          70.0          69.7          69.6
# 4   Frederiksberg          75.6          73.7          72.7          72.8
# 5          Dragør          80.5          78.8          78.5          78.5
# 6          Tårnby          79.0          76.3          75.4          75.8
# 8     Albertslund          73.1          69.2          67.5          67.4
# 9        Ballerup          75.9          72.9          71.9          72.0
# 10        Brøndby          72.3          69.6          68.3          68.2
# 11       Gentofte          79.2          76.6          76.4          76.1
# 12       Gladsaxe          77.9          75.0          74.1          73.6
# 13       Glostrup          79.2          76.1          74.5          75.0
#
#     emp_rate2012  emp_rate2013  emp_rate2014  emp_rate2015  emp_rate2016  \
# 3           69.4          69.7          70.0          70.8          71.5
# 4           73.0          73.3          73.5          74.0          74.7
# 5           78.7          78.7          78.9          78.6          79.2
# 6           75.4          75.8          75.7          76.5          77.4
# 8           66.5          67.0          67.4          68.7          68.8
# 9           71.4          71.0          71.8          72.8          73.6
# 10          67.4          67.5          67.3          68.0          69.1
# 11          75.5          75.2          74.7          75.1          75.2
# 12          73.2          73.1          73.4          74.1          74.3
# 13          74.7          74.8          74.4          75.0          75.5
#
#     emp_rate2017  emp_rate2018  emp_rate2019  emp_rate2020  emp_rate2021  \
# 3           72.2          73.2          73.9          72.8          76.1
# 4           75.6          76.5          77.0          76.6          79.1
# 5           80.4          81.2          81.0          80.4          82.3
# 6           77.6          78.0          78.9          77.5          79.7
# 8           70.2          71.3          71.5          70.8          73.6
# 9           74.5          75.3          75.5          74.7          77.0
# 10          69.4          70.2          71.0          69.5          73.2
# 11          76.1          76.6          77.0          76.1          78.2
# 12          75.3          76.3          77.3          76.6          79.1
# 13          76.0          76.5          77.5          76.6          78.8
#
#     emp_rate2022  emp_rate2023
# 3           76.7          76.8
# 4           79.5          79.7
# 5           83.9          83.3
# 6           80.5          80.5
# 8           75.1          75.1
# 9           78.1          77.7
# 10          74.2          74.0
# 11          78.5          78.5
# 12          79.4          79.1
# 13          79.0          79.0

# %% [markdown]
# Very important: **reset index**

# %%
RAS = RAS.reset_index(drop=True) # drop old index too
RAS.iloc[0:4,:]
# Out:
#     municipality  emp_rate2008  emp_rate2009  emp_rate2010  emp_rate2011  \
# 0     Copenhagen          72.5          70.0          69.7          69.6
# 1  Frederiksberg          75.6          73.7          72.7          72.8
# 2         Dragør          80.5          78.8          78.5          78.5
# 3         Tårnby          79.0          76.3          75.4          75.8
#
#    emp_rate2012  emp_rate2013  emp_rate2014  emp_rate2015  emp_rate2016  \
# 0          69.4          69.7          70.0          70.8          71.5
# 1          73.0          73.3          73.5          74.0          74.7
# 2          78.7          78.7          78.9          78.6          79.2
# 3          75.4          75.8          75.7          76.5          77.4
#
#    emp_rate2017  emp_rate2018  emp_rate2019  emp_rate2020  emp_rate2021  \
# 0          72.2          73.2          73.9          72.8          76.1
# 1          75.6          76.5          77.0          76.6          79.1
# 2          80.4          81.2          81.0          80.4          82.3
# 3          77.6          78.0          78.9          77.5          79.7
#
#    emp_rate2022  emp_rate2023
# 0          76.7          76.8
# 1          79.5          79.7
# 2          83.9          83.3
# 3          80.5          80.5

# %% [markdown]
# #### 1.2.4. <a id='toc1_2_4_'></a>[Summary statistics](#toc0_)
#
# To get an overview of employments across municipalities we can use the function `df.describe()`.

# %%
RAS.describe().style.format('{:.1f}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_c0c86">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c0c86_level0_col0" class="col_heading level0 col0" >emp_rate2008</th>
#       <th id="T_c0c86_level0_col1" class="col_heading level0 col1" >emp_rate2009</th>
#       <th id="T_c0c86_level0_col2" class="col_heading level0 col2" >emp_rate2010</th>
#       <th id="T_c0c86_level0_col3" class="col_heading level0 col3" >emp_rate2011</th>
#       <th id="T_c0c86_level0_col4" class="col_heading level0 col4" >emp_rate2012</th>
#       <th id="T_c0c86_level0_col5" class="col_heading level0 col5" >emp_rate2013</th>
#       <th id="T_c0c86_level0_col6" class="col_heading level0 col6" >emp_rate2014</th>
#       <th id="T_c0c86_level0_col7" class="col_heading level0 col7" >emp_rate2015</th>
#       <th id="T_c0c86_level0_col8" class="col_heading level0 col8" >emp_rate2016</th>
#       <th id="T_c0c86_level0_col9" class="col_heading level0 col9" >emp_rate2017</th>
#       <th id="T_c0c86_level0_col10" class="col_heading level0 col10" >emp_rate2018</th>
#       <th id="T_c0c86_level0_col11" class="col_heading level0 col11" >emp_rate2019</th>
#       <th id="T_c0c86_level0_col12" class="col_heading level0 col12" >emp_rate2020</th>
#       <th id="T_c0c86_level0_col13" class="col_heading level0 col13" >emp_rate2021</th>
#       <th id="T_c0c86_level0_col14" class="col_heading level0 col14" >emp_rate2022</th>
#       <th id="T_c0c86_level0_col15" class="col_heading level0 col15" >emp_rate2023</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c0c86_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_c0c86_row0_col0" class="data row0 col0" >99.0</td>
#       <td id="T_c0c86_row0_col1" class="data row0 col1" >99.0</td>
#       <td id="T_c0c86_row0_col2" class="data row0 col2" >99.0</td>
#       <td id="T_c0c86_row0_col3" class="data row0 col3" >99.0</td>
#       <td id="T_c0c86_row0_col4" class="data row0 col4" >99.0</td>
#       <td id="T_c0c86_row0_col5" class="data row0 col5" >99.0</td>
#       <td id="T_c0c86_row0_col6" class="data row0 col6" >99.0</td>
#       <td id="T_c0c86_row0_col7" class="data row0 col7" >99.0</td>
#       <td id="T_c0c86_row0_col8" class="data row0 col8" >99.0</td>
#       <td id="T_c0c86_row0_col9" class="data row0 col9" >99.0</td>
#       <td id="T_c0c86_row0_col10" class="data row0 col10" >99.0</td>
#       <td id="T_c0c86_row0_col11" class="data row0 col11" >99.0</td>
#       <td id="T_c0c86_row0_col12" class="data row0 col12" >99.0</td>
#       <td id="T_c0c86_row0_col13" class="data row0 col13" >99.0</td>
#       <td id="T_c0c86_row0_col14" class="data row0 col14" >99.0</td>
#       <td id="T_c0c86_row0_col15" class="data row0 col15" >99.0</td>
#     </tr>
#     <tr>
#       <th id="T_c0c86_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_c0c86_row1_col0" class="data row1 col0" >76.6</td>
#       <td id="T_c0c86_row1_col1" class="data row1 col1" >73.4</td>
#       <td id="T_c0c86_row1_col2" class="data row1 col2" >72.8</td>
#       <td id="T_c0c86_row1_col3" class="data row1 col3" >72.6</td>
#       <td id="T_c0c86_row1_col4" class="data row1 col4" >72.0</td>
#       <td id="T_c0c86_row1_col5" class="data row1 col5" >72.1</td>
#       <td id="T_c0c86_row1_col6" class="data row1 col6" >72.4</td>
#       <td id="T_c0c86_row1_col7" class="data row1 col7" >72.9</td>
#       <td id="T_c0c86_row1_col8" class="data row1 col8" >73.7</td>
#       <td id="T_c0c86_row1_col9" class="data row1 col9" >74.5</td>
#       <td id="T_c0c86_row1_col10" class="data row1 col10" >75.5</td>
#       <td id="T_c0c86_row1_col11" class="data row1 col11" >76.0</td>
#       <td id="T_c0c86_row1_col12" class="data row1 col12" >75.5</td>
#       <td id="T_c0c86_row1_col13" class="data row1 col13" >77.7</td>
#       <td id="T_c0c86_row1_col14" class="data row1 col14" >78.2</td>
#       <td id="T_c0c86_row1_col15" class="data row1 col15" >78.1</td>
#     </tr>
#     <tr>
#       <th id="T_c0c86_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_c0c86_row2_col0" class="data row2 col0" >3.7</td>
#       <td id="T_c0c86_row2_col1" class="data row2 col1" >3.6</td>
#       <td id="T_c0c86_row2_col2" class="data row2 col2" >3.6</td>
#       <td id="T_c0c86_row2_col3" class="data row2 col3" >3.7</td>
#       <td id="T_c0c86_row2_col4" class="data row2 col4" >3.8</td>
#       <td id="T_c0c86_row2_col5" class="data row2 col5" >3.7</td>
#       <td id="T_c0c86_row2_col6" class="data row2 col6" >3.7</td>
#       <td id="T_c0c86_row2_col7" class="data row2 col7" >3.6</td>
#       <td id="T_c0c86_row2_col8" class="data row2 col8" >3.5</td>
#       <td id="T_c0c86_row2_col9" class="data row2 col9" >3.6</td>
#       <td id="T_c0c86_row2_col10" class="data row2 col10" >3.4</td>
#       <td id="T_c0c86_row2_col11" class="data row2 col11" >3.4</td>
#       <td id="T_c0c86_row2_col12" class="data row2 col12" >3.3</td>
#       <td id="T_c0c86_row2_col13" class="data row2 col13" >3.1</td>
#       <td id="T_c0c86_row2_col14" class="data row2 col14" >3.0</td>
#       <td id="T_c0c86_row2_col15" class="data row2 col15" >3.0</td>
#     </tr>
#     <tr>
#       <th id="T_c0c86_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_c0c86_row3_col0" class="data row3 col0" >62.9</td>
#       <td id="T_c0c86_row3_col1" class="data row3 col1" >63.4</td>
#       <td id="T_c0c86_row3_col2" class="data row3 col2" >62.4</td>
#       <td id="T_c0c86_row3_col3" class="data row3 col3" >61.5</td>
#       <td id="T_c0c86_row3_col4" class="data row3 col4" >60.7</td>
#       <td id="T_c0c86_row3_col5" class="data row3 col5" >61.2</td>
#       <td id="T_c0c86_row3_col6" class="data row3 col6" >61.6</td>
#       <td id="T_c0c86_row3_col7" class="data row3 col7" >62.2</td>
#       <td id="T_c0c86_row3_col8" class="data row3 col8" >62.6</td>
#       <td id="T_c0c86_row3_col9" class="data row3 col9" >63.1</td>
#       <td id="T_c0c86_row3_col10" class="data row3 col10" >64.3</td>
#       <td id="T_c0c86_row3_col11" class="data row3 col11" >65.4</td>
#       <td id="T_c0c86_row3_col12" class="data row3 col12" >64.8</td>
#       <td id="T_c0c86_row3_col13" class="data row3 col13" >67.0</td>
#       <td id="T_c0c86_row3_col14" class="data row3 col14" >68.2</td>
#       <td id="T_c0c86_row3_col15" class="data row3 col15" >68.3</td>
#     </tr>
#     <tr>
#       <th id="T_c0c86_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_c0c86_row4_col0" class="data row4 col0" >74.7</td>
#       <td id="T_c0c86_row4_col1" class="data row4 col1" >71.3</td>
#       <td id="T_c0c86_row4_col2" class="data row4 col2" >70.5</td>
#       <td id="T_c0c86_row4_col3" class="data row4 col3" >70.0</td>
#       <td id="T_c0c86_row4_col4" class="data row4 col4" >69.5</td>
#       <td id="T_c0c86_row4_col5" class="data row4 col5" >69.7</td>
#       <td id="T_c0c86_row4_col6" class="data row4 col6" >70.2</td>
#       <td id="T_c0c86_row4_col7" class="data row4 col7" >70.8</td>
#       <td id="T_c0c86_row4_col8" class="data row4 col8" >71.5</td>
#       <td id="T_c0c86_row4_col9" class="data row4 col9" >72.5</td>
#       <td id="T_c0c86_row4_col10" class="data row4 col10" >73.5</td>
#       <td id="T_c0c86_row4_col11" class="data row4 col11" >74.1</td>
#       <td id="T_c0c86_row4_col12" class="data row4 col12" >73.8</td>
#       <td id="T_c0c86_row4_col13" class="data row4 col13" >76.2</td>
#       <td id="T_c0c86_row4_col14" class="data row4 col14" >76.4</td>
#       <td id="T_c0c86_row4_col15" class="data row4 col15" >76.3</td>
#     </tr>
#     <tr>
#       <th id="T_c0c86_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_c0c86_row5_col0" class="data row5 col0" >76.8</td>
#       <td id="T_c0c86_row5_col1" class="data row5 col1" >73.3</td>
#       <td id="T_c0c86_row5_col2" class="data row5 col2" >72.9</td>
#       <td id="T_c0c86_row5_col3" class="data row5 col3" >72.6</td>
#       <td id="T_c0c86_row5_col4" class="data row5 col4" >72.1</td>
#       <td id="T_c0c86_row5_col5" class="data row5 col5" >72.2</td>
#       <td id="T_c0c86_row5_col6" class="data row5 col6" >72.6</td>
#       <td id="T_c0c86_

# %% [markdown]
# ### 1.3. <a id='toc1_3_'></a>[Step 3. Structure](#toc0_)

# %% [markdown]
# Think of a dataset as having:
#
# 1. `id`, here `municipality`.
# 1. `period`, here `year`.
# 1. `variables`, here `empl`(oyment)
#
# Datasets are:
#
# 1. **Longer** if they have more *rows*
# 1. **Wider** if they have more *columns*
#
# In economics, we often like panel data sets, which are:
#
# 1. **Wide** in `variables` (i.e. one column, one variable)
# 1. **Long** in (`id`,`period`) (i.e. one row per observation)

# %% [markdown]
# Conversion can be done with `pd.wide_to_long`:
#
# 1. `i` is `id`
# 1. `j` is `period`
# 1. The wide format variables are assumed to start with the `stubnames`.

# %%
RAS_long = pd.wide_to_long(RAS,stubnames='emp_rate',i='municipality',j='year')
RAS_long.head(5)
# Out:
#                     emp_rate
# municipality  year
# Copenhagen    2008      72.5
# Frederiksberg 2008      75.6
# Dragør        2008      80.5
# Tårnby        2008      79.0
# Albertslund   2008      73.1

# %% [markdown]
# **More genaral alternative:**

# %%
RAS_long_ = RAS.melt(id_vars='municipality', var_name='year',value_name='emp_rate')
RAS_long_['year'] = RAS_long_['year'].str.replace('emp_rate', '').astype(int)
RAS_long_.head(5)
# Out:
#     municipality  year  emp_rate
# 0     Copenhagen  2008      72.5
# 1  Frederiksberg  2008      75.6
# 2         Dragør  2008      80.5
# 3         Tårnby  2008      79.0
# 4    Albertslund  2008      73.1

# %% [markdown]
# **Note:** The variables `municipality` and `year`  are now in the index!! We see that because they are "below" `empl` in the `head` overview.

# %%
# the index variable now consists of tuples. 
print(RAS_long.index.values[:3])
# Out:
# [('Copenhagen', 2008) ('Frederiksberg', 2008) ('Dragør', 2008)]

# %% [markdown]
# The index is now a [Multiindex](https://pandas.pydata.org/docs/user_guide/advanced.html#multiindex-advanced-indexing), as it has multiple levels.
#
# We can **select a specific municipality** using ``.xs``:

# %%
RAS_long.xs('Roskilde',level='municipality')
# Out:
#       emp_rate
# year
# 2008      79.1
# 2009      76.3
# 2010      75.2
# 2011      74.9
# 2012      74.1
# 2013      74.0
# 2014      74.0
# 2015      74.5
# 2016      75.6
# 2017      76.8
# 2018      77.7
# 2019      78.1
# 2020      77.6
# 2021      79.8
# 2022      80.6
# 2023      80.5

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)

municipalities = ['Copenhagen','Roskilde','Lejre']
for m in municipalities:
    y = RAS_long.xs(m,level='municipality')
    ax.plot(y.index,y['emp_rate'],ls='-',marker='o',label=m)

ax.set_ylabel('percent');
ax.set_ylim([60,90])
ax.set_xlabel('year')
# y
ax.set_xticks(y.index,labels=y.index)
ax.set_xticklabels(y.index,rotation=270)
ax.legend(frameon=True,ncol=3,fontsize=12);

# %% [markdown]
# ## 2. <a id='toc2_'></a>[Employment and participation rate in Danish municipalities](#toc0_)

# %% [markdown]
# We now read in RAS data for both the employment and participation rate in each municipality.
#
# Here we do the cleaning, renaming and structuring more condensed.

# %%
# a. load
RAS = pd.read_excel('data/raw/RAS200.xlsx',skiprows=2)
print('initial:')
display(RAS.head(5).iloc[:,0:7])

# b. clean and rename
RAS = RAS.drop(columns = [f'Unnamed: {i}' for i in range(3)])

RAS = RAS.rename(columns = {'Unnamed: 3':'variable', 'Unnamed: 4':'municipality'})
years = [col for col in RAS.columns if col.isnumeric()]
RAS = RAS.rename(columns = {str(i): f'value{i}' for i in years})

# c. fill missing
RAS['variable'] = RAS['variable'].ffill()
RAS['variable'] = RAS['variable'].str.replace('Employment rate','emp_rate')
RAS['variable'] = RAS['variable'].str.replace('Economic activity rate','part_rate')

# d. drop rows with missing values - denoted na
RAS = RAS.dropna()

# e. remove non-municipalities
for val in ['Region','Province', 'All Denmark']: 
    I = RAS.municipality.str.contains(val)
    print(I.sum())
    RAS = RAS.drop(RAS[I].index) # .index -> get the indexes of the series
    
print('cleaned:')
RAS.iloc[:5,:5]
# Out:
# initial:
#   Unnamed: 0   Unnamed: 1 Unnamed: 2       Unnamed: 3  \
# 0      Total  16-64 years      Total  Employment rate
# 1        NaN          NaN        NaN              NaN
# 2        NaN          NaN        NaN              NaN
# 3        NaN          NaN        NaN              NaN
# 4        NaN          NaN        NaN              NaN
#
#                 Unnamed: 4  2008  2009
# 0              All Denmark  76.0  72.8
# 1       Region Hovedstaden  75.8  73.3
# 2  Province Byen København  73.4  71.0
# 3               Copenhagen  72.5  70.0
# 4            Frederiksberg  75.6  73.7
# 10
# 22
# 2
# cleaned:
#    variable   municipality  value2008  value2009  value2010
# 3  emp_rate     Copenhagen       72.5       70.0       69.7
# 4  emp_rate  Frederiksberg       75.6       73.7       72.7
# 5  emp_rate         Dragør       80.5       78.8       78.5
# 6  emp_rate         Tårnby       79.0       76.3       75.4
# 8  emp_rate    Albertslund       73.1       69.2       67.5

# %% [markdown]
# **Convert** wide to long:

# %%
RAS_long_ = pd.wide_to_long(df=RAS,stubnames='value',i=('municipality','variable'),j='year')
RAS_long_.head(5)
# Out:
#                             value
# municipality variable year
# Copenhagen   emp_rate 2008   72.5
#                       2009   70.0
#                       2010   69.7
#                       2011   69.6
#                       2012   69.4

# %%
RAS_long = RAS_long_.pivot_table(index=('municipality','year'),columns=['variable'],values='value').rename_axis(None,axis=1)
RAS_long.head(5)
# Out:
#                    emp_rate  part_rate
# municipality year
# Aabenraa     2008      74.6       76.3
#              2009      71.6       75.2
#              2010      70.9       74.5
#              2011      70.2       74.0
#              2012      69.5       73.7

# %% [markdown]
# Compare employment rate and participation rate:

# %%
fig = plt.figure(figsize=(12,4))

municipalities = ['Copenhagen','Roskilde','Lejre']
for i,m in enumerate(municipalities):

    ax = fig.add_subplot(1,3,i+1)

    y = RAS_long.xs(m,level='municipality')
    ax.plot(y.index,y['emp_rate'],ls='-',marker='o',label='employment rate')
    ax.plot(y.index,y['part_rate'],ls='-',marker='o',label='participation rate')

    ax.set_title(m)
    ax.set_ylabel('percent');
    ax.set_ylim([60,90])
    ax.set_xlabel('year')
    ax.set_xticks(y.index[::2])
    ax.set_xticklabels(y.index[::2],rotation=270)
    if i == 0:
        ax.legend(frameon=True,fontsize=12);

fig.tight_layout()

# %% [markdown]
# ## 3. <a id='toc3_'></a>[Income in Danish municipalities](#toc0_)

# %% [markdown]
# We now read in the avg. disposable income in each municipality.

# %%
# a. load
INDKP = pd.read_excel('data/raw/INDKP101.xlsx',skiprows=2)
print('initial:')
display(INDKP.head(5).iloc[:,0:7])

# b. clean and rename
INDKP = INDKP.drop(columns = [f'Unnamed: {i}' for i in range(3)])

INDKP = INDKP.rename(columns = {'Unnamed: 3':'municipality'})
years = [col for col in INDKP.columns if col.isnumeric()]
INDKP = INDKP.rename(columns = {str(i): f'inc{i}' for i in years})

# d. drop rows with missing values - denoted na
INDKP = INDKP.dropna()

# e. remove non-municipalities
for val in ['Region','Province','All Denmark']: 
    I = INDKP.municipality.str.contains(val)
    INDKP = INDKP.drop(INDKP[I].index) # .index -> get the indexes of the series
    
print('cleaned:')
INDKP.iloc[:5,:5]
# Out:
# initial:
#                             Unnamed: 0            Unnamed: 1  \
# 0  1 Disposable income (2+30-31-32-35)  Men and women, total
# 1                                  NaN                   NaN
# 2                                  NaN                   NaN
# 3                                  NaN                   NaN
# 4                                  NaN                   NaN
#
#                             Unnamed: 2               Unnamed: 3     1987  \
# 0  Average income for all people (DKK)              All Denmark  78135.0
# 1                                  NaN  Province Byen København  78012.0
# 2                                  NaN               Copenhagen  75356.0
# 3                                  NaN            Frederiksberg  85428.0
# 4                                  NaN                   Dragør  97966.0
#
#       1988      1989
# 0  82304.0   87011.0
# 1  82061.0   85804.0
# 2  79444.0   82895.0
# 3  89924.0   94626.0
# 4  99867.0  106167.0
# cleaned:
#     municipality  inc1987  inc1988   inc1989   inc1990
# 2     Copenhagen  75356.0  79444.0   82895.0   85421.0
# 3  Frederiksberg  85428.0  89924.0   94626.0   98916.0
# 4         Dragør  97966.0  99867.0  106167.0  109441.0
# 5         Tårnby  87598.0  90789.0   95053.0   98313.0
# 7    Albertslund  83540.0  87075.0   90616.0   93620.0

# %% [markdown]
# **Convert** wide to long:

# %%
INDKP_long = pd.wide_to_long(df=INDKP,stubnames='inc',i='municipality',j='year')
INDKP_long.head(5)
# Out:
#                         inc
# municipality  year
# Copenhagen    1987  75356.0
# Frederiksberg 1987  85428.0
# Dragør        1987  97966.0
# Tårnby        1987  87598.0
# Albertslund   1987  83540.0

# %% [markdown]
# ## 4. <a id='toc4_'></a>[Area in Danish municipalities](#toc0_)

# %% [markdown]
# We now read in the area of each municipality in square kilometers.

# %%
# a. load
ARE = pd.read_excel('data/raw/ARE207.xlsx',skiprows=2)
print('initial:')
display(ARE.head(5).iloc[:,0:7])

# b. clean and rename
ARE = ARE.rename(columns = {'Unnamed: 0':'municipality','2008': 'area_2008'})

# c. drop rows with missing values - denoted na
ARE = ARE.dropna()

# d. remove non-municipalities
for val in ['Region','Province','All Denmark']: 
    I = ARE.municipality.str.contains(val)
    ARE = ARE.drop(ARE[I].index) # .index -> get the indexes of the series
    
print('cleaned:')
ARE.iloc[:5,:5]
# Out:
# initial:
#            Unnamed: 0      2008
# 0         All Denmark  43098.31
# 1  Region Hovedstaden   2561.27
# 2          Copenhagen     88.25
# 3       Frederiksberg      8.77
# 4              Dragør     18.14
# cleaned:
#     municipality  area_2008
# 2     Copenhagen      88.25
# 3  Frederiksberg       8.77
# 4         Dragør      18.14
# 5         Tårnby      64.95
# 6    Albertslund      23.04

# %% [markdown]
# ## 5. <a id='toc5_'></a>[Writing data](#toc0_)

# %% [markdown]
# As with reading in data, we have the corresponding functions for **writing data**:
#
# * CSV: `pd.to_csv()`
# * SAS: `pd.to_sas()`
# * Excel: `pd.to_excel()`
# * Stata: `pd.to_stata()`
# * Parquet: `pd.to_parquet()`

# %% [markdown]
# Let's **save our dataset to CSV form**. We will set `index=False` to avoid saving the index (which does not mean anything here but can in other contexts be an annoying thing).

# %%
RAS_long.to_csv('data/RAS200_long.csv',index=True)
INDKP_long.to_csv('data/INDKP101_long.csv',index=True)
ARE.to_csv('data/ARE207_long.csv',index=False)

# %% [markdown]
# ## 6. <a id='toc6_'></a>[Summary](#toc0_)

# %% [markdown]
# The main takeways are:
#
# - Loading data `pd.read_*` and saving data `pd.to_*`
# - Clean data (`.rename`, `.drop`, `.astype`, `dropna` etc.)
# - Structure data (`.wide_to_long`, `.melt`, `.pivot_table`)
# - Multiindex in pandel data (`.xs`)
# - Analyzing and plotting data
